# %% [markdown]
# # Capstone Assignment: Complete Data Analysis Project
# *Course:* GRTR 513 Decoding Python to Fuel Your Research
# *Due:* **Friday, August 7 at 1:00 pm** (covers Weeks 1-7 in the [Udemy learning path](https://concordia.udemy.com/learning-paths/10727613/))
#
# > **Instructions:** This capstone assignment brings together everything you've learned: Python fundamentals, NumPy, Pandas, and data visualization.
# > You will perform a **complete end-to-end data analysis** on a dataset of your choice.
# > Focus on telling a clear story with your data.
#
# **Fill this in!**
#
# ---
#
# **Student Name:** Tanzir Bin Razzaque
# **Chosen Dataset:** goodreads_books.csv
# **Dataset Source (URL or filename):** https://moodle.concordia.ca/moodle/pluginfile.php/7929315/mod_folder/content/0/goodreads_books.csv?forcedownload=1
#
# ---
#
# ## Learning Objectives
# This capstone demonstrates your ability to:
# - Load and clean real-world datasets
# - Handle missing or problematic data
# - Calculate meaningful summary statistics
# - Create effective visualizations
# - Extract and communicate insights from data
# - Apply appropriate Python tools for each task
#
# ## Assignment Overview
# You will complete **four main tasks**:
# 1. **Load and Clean Data** - Import your dataset and prepare it for analysis
# 2. **Produce Summaries** - Calculate and present key statistics
# 3. **Create Visualizations** - Make 3-4 plots that reveal patterns in your data
# 4. **Write Your Insights** - Explain what you discovered and what it means
#
# ### What to Use
# - Python fundamentals (variables, loops, conditions, functions)
# - NumPy arrays for numerical operations
# - Pandas for data manipulation (DataFrames, Series)
# - Matplotlib and/or Seaborn for visualization
# - Choose the **best tool for each job** - don't force yourself to use everything everywhere!
#
# ### General Tips
# - **Start simple:** Get your data loaded and explore it before diving into complex analysis
# - **Ask questions:** What do you want to know about this data? Let questions guide your analysis
# - **Tell a story:** Your insights should connect your visualizations and summaries into a coherent narrative
# - **Document your work:** Use comments and Markdown cells to explain your choices

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ---
# ## Part 1: Load and Clean the Data
#
# Pick one dataset to work with. Ideally, this will be the same dataset you've used throughout the course so you're already familiar with it, but feel free to switch it up. As a reminder, there is a list of curated datesets on Moodle, but you can also bring your own as long as you also upload it together with your submission.
#
# ### Task 1.1: Inspect the Data
# Load your dataset and perform an initial exploration:
# 1. Load the data using `pd.read_csv()` (adjust parameters as needed)
# 2. Display basic information:
#    - First few rows
#    - Shape (rows and columns)
#    - Column names and data types
#    - Summary statistics
# 3. Check for any obvious issues:
#    - Missing values
#    - Unexpected data types
#    - Duplicate rows

# %%
from IPython.display import display
# TODO: Set your data file path
DATA_PATH = "./data/goodreads_books.csv"

# Load the dataset
# YOUR CODE HERE
df = pd.read_csv(DATA_PATH, on_bad_lines="skip")

# Display first few rows
# YOUR CODE HERE
df.head()
# Print shape
# YOUR CODE HERE
display(df.shape)
# Print column info
# YOUR CODE HERE
display(df.info())
# Summary statistics
# YOUR CODE HERE
display(df.describe())
# Check for missing values
# YOUR CODE HERE
display(df.isna().any())
# Check for duplicates
# YOUR CODE HERE
display(df.duplicated().any())
# Out:
# (11123, 12)
# <class 'pandas.DataFrame'>
# RangeIndex: 11123 entries, 0 to 11122
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   bookID              11123 non-null  int64
#  1   title               11123 non-null  str
#  2   authors             11123 non-null  str
#  3   average_rating      11123 non-null  float64
#  4   isbn                11123 non-null  str
#  5   isbn13              11123 non-null  int64
#  6   language_code       11123 non-null  str
#  7     num_pages         11123 non-null  int64
#  8   ratings_count       11123 non-null  int64
#  9   text_reviews_count  11123 non-null  int64
#  10  publication_date    11123 non-null  str
#  11  publisher           11123 non-null  str
# dtypes: float64(1), int64(5), str(6)
# memory usage: 1.0 MB
# None
#              bookID  average_rating        isbn13     num_pages  \
# count  11123.000000    11123.000000  1.112300e+04  11123.000000
# ...

# %% [markdown]
# ### Task 1.2: Handle Missing Data
# Clean your dataset by addressing missing values and any other data quality issues:
#
# Choose one or more of the following strategies (based on what makes sense for your data):
# 1. **Remove rows** with missing values in critical columns
# 2. **Fill missing values** with appropriate defaults (mean, median, mode, or a specific value)
# 3. **Drop columns** that are mostly empty or not useful for analysis
# 4. **Fix data types** if any columns are incorrectly typed
# 5. **Remove duplicates** if present
#
# **After cleaning:**
# - Store the cleaned data in a new DataFrame called `df_clean`
# - Print the new shape and confirm missing values are handled
# - Save the cleaned data: `df_clean.to_csv('cleaned_data.csv', index=False)`

# %%
# Create a copy to preserve original data
df_clean = df.copy()

# YOUR CLEANING CODE HERE
# Example approaches:
# df_clean = df_clean.dropna(subset=['important_column'])
# df_clean['column'].fillna(df_clean['column'].mean(), inplace=True)
# df_clean = df_clean.drop(columns=['useless_column'])
# df_clean = df_clean.drop_duplicates()

# Print results after cleaning
print(f"Original shape: {df.shape}")
print(f"Cleaned shape: {df_clean.shape}")
print(f"\nRemaining missing values:\n{df_clean.isnull().sum()}")

# Save cleaned data
df_clean.to_csv('cleaned_data.csv', index=False)
print("\nCleaned data saved to 'cleaned_data.csv'")

# %% [markdown]
# ---
# ## Part 2: Produce Summaries
#
# Create **at least TWO different summaries** that provide meaningful insights into your data. Choose from:
#
# 1. **Group-by summaries:** Calculate statistics for different categories (e.g., mean sales by region, average temperature by month)
# 2. **Correlation analysis:** Find relationships between numeric variables
# 3. **Time-based aggregation:** Summarize data by time periods (if applicable)
# 4. **Custom calculations:** Create new metrics or derived values (e.g., percentages, ratios, growth rates)
# 5. **Top/Bottom N analysis:** Find highest/lowest values by some criteria
# 6. **Pivot tables:** Cross-tabulate data to compare multiple dimensions
#
# **For each summary:**
# - Display the results clearly (use DataFrames or Series)
#
# **Tip:** Think about questions you want to answer! Examples:
# - "What's the average X for each category of Y?"
# - "Which groups have the highest/lowest values?"
# - "How do these variables relate to each other?"
# - "What trends exist over time?"

# %%
# Summary 1: (Describe what you're calculating)
# YOUR CODE HERE

print("Summary 1:")
# Display results

# %%
# Summary 2: (Describe what you're calculating)
# YOUR CODE HERE

print("Summary 2:")
# Display results

# %% [markdown]
# ---
# ## Part 3: Derive Information and Produce Visualizations
#
# Create **3-4 visualizations** that effectively communicate patterns, trends, or relationships in your data.
#
# **Requirements:**
# 1. Use at least **THREE different plot types** (choose what's appropriate for your data):
#    - Bar chart / Horizontal bar chart
#    - Line plot / Area plot
#    - Scatter plot
#    - Histogram
#    - Box plot / Violin plot
#    - Heatmap
#
# 2. Each plot must have:
#    - Clear, descriptive title
#    - Labeled axes (with units if applicable)
#    - Appropriate colors/styling
#    - Readable text size
#
# 3. **Below each plot**, add a markdown cell explaining in 1-3 sentences:
#    - What does this plot show?
#    - What patterns or insights does it reveal?
#    - Why did you choose this visualization type?
#
# **Tips for effective visualizations:**
# - Choose plot types that match your data (categorical → bar/pie, continuous → line/scatter, distributions → histogram/box)
# - Use color meaningfully (to distinguish categories, not randomly)
# - Keep it simple - don't cram too much into one plot
# - Consider your audience - would they understand this plot?

# %%
# Visualization 1: (Type of plot and what it shows)
# YOUR CODE HERE

# Example structure:
# plt.figure(figsize=(10, 6))
# ... plotting code ...
# plt.title('Your Title Here', fontsize=14, fontweight='bold')
# plt.xlabel('X Label')
# plt.ylabel('Y Label')
# plt.tight_layout()
# plt.show()

# %% [markdown]
# **Visualization 1 Analysis:**
#
# (write 1-3 sentences here)

# %%
# Visualization 2: (Type of plot and what it shows)
# YOUR CODE HERE

# %% [markdown]
# **Visualization 2 Analysis:**
#
# (write 1-3 sentences here)

# %%
# Visualization 3: (Type of plot and what it shows)
# YOUR CODE HERE

# %% [markdown]
# **Visualization 3 Analysis:**
#
# (write 1-3 sentences here)

# %% [markdown]
# ---
# ## Submission Checklist
#
# Before submitting, verify that you have:
#
# ### Part 1: Load and Clean Data
# - [ ] Data loaded successfully with pd.read_csv()
# - [ ] Initial inspection completed (shape, types, missing values, duplicates)
# - [ ] Description of dataset and issues written
# - [ ] At least one cleaning strategy applied
# - [ ] Cleaned data saved as 'cleaned_data.csv'
# - [ ] Cleaning decisions explained as comments or markdown
#
# ### Part 2: Produce Summaries
# - [ ] At least two different summary analyses completed
# - [ ] Each summary is clearly displayed
# - [ ] Summaries answer meaningful questions about the data
#
# ### Part 3: Visualizations
# - [ ] 3 or more visualizations created
# - [ ] At least THREE different plot types used
# - [ ] All plots have titles and labeled axes
# - [ ] Each visualization has an accompanying analysis
# - [ ] Plot types are appropriate for the data being shown
#
# ### General Requirements
# - [ ] All code cells run without errors
# - [ ] Code is well-commented
# - [ ] Markdown explanations are clear and complete
# - [ ] Student name and dataset information filled in at the top
# - [ ] Notebook is organized and easy to follow
#
# ---
#
# ## Grading Rubric (100 points total)
#
# ### Part 1: Load and Clean Data (25 points)
# - **Data loading and inspection (10 pts):** Successfully loads data; thoroughly examines shape, types, missing values, duplicates
# - **Data cleaning (10 pts):** Applies appropriate cleaning strategies; makes reasonable decisions about handling issues
# - **Documentation (5 pts):** Clearly explains dataset and cleaning decisions
#
# ### Part 2: Summaries (25 points)
# - **Quality of summaries (15 pts):** Creates meaningful, well-calculated summaries using appropriate Pandas methods
# - **Variety (5 pts):** Uses different summary techniques
# - **Interpretation (5 pts):** Provides clear explanations of what each summary reveals as comments or additional Markdown cells
#
# ### Part 3: Visualizations (25 points)
# - **Plot quality (15 pts):** Creates clear, well-labeled, appropriately-styled visualizations
# - **Plot variety (5 pts):** Uses at least 3 different plot types; choices are appropriate for the data
# - **Analysis (5 pts):** Provides thoughtful interpretation of each visualization
#
# ### Code Quality and Documentation (25 points)
# - **Code functionality (18 pts):** All code runs without errors; uses Python/NumPy/Pandas correctly
# - **Documentation (7 pts):** Code is commented; overall notebook organization is logical
#
# ---
#
# ## Submission Instructions
#
# Submit the following via Moodle by **Friday, August 7 at 1:00 pm**:
#
# 1. **This completed Jupyter notebook** (.ipynb file)
# 2. **Your cleaned dataset** (cleaned_data.csv)
# 3. **Your original dataset** (if using a custom dataset not from Moodle)
#
# **File naming convention:**
# - Notebook: `LastName_FirstName_Capstone.ipynb`
# - Cleaned data: `cleaned_data.csv` (as specified in the code)
#
# ---
#
# ## Academic Integrity
#
# This is an **individual assignment**. You may:
# - Use course materials, official documentation, and recommended resources
# - Discuss general approaches with classmates
# - Ask the facilitator for clarification
#
# You may **not**:
# - Share code with classmates or copy from others
# - Submit work that is not your own
#
# **All code, analysis, and writing must be your own work.** Cite any external resources used beyond official course materials and documentation.
#
# ---
#
# ## Good luck!
#
# Remember: this assignment is about demonstrating what you've learned. Focus on:
# - Understanding your data
# - Making reasonable analytical choices
# - Communicating clearly
# - Showing your work
#
# Let the data guide your story!
