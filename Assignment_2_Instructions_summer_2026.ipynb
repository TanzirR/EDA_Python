# %% [markdown]
# # Assignment 2: Functions and Data Structures
# *Course:* GRTR 513 Decoding Python to Fuel Your Research
# *Due:* **July 10, 2026, 1:00 pm**
# *Estimated time:* ~ 2 hours
#
# > **Instructions:** This assignment focuses on **functions, modular code, and data structures** (lists, dictionaries, tuples, sets).
# > You will load a CSV file using the `csv` module, organize its data using appropriate structures, and write reusable functions.
# > **Important:** You should work with the **same dataset** you used in Assignment 1 (or a new one if you prefer). If you choose to work with a dataset that's not available in the Moodle, you **must** upload it together with your notebook submission.
#
# **Fill this in!** *(You can double-click any notebook cell to edit)*
#
# ---
#
# **Student Name:** Tanzir Bin Razzaque
# **Chosen Dataset:** goodreads_books
# **Dataset Source (URL or filename):** https://moodle.concordia.ca/moodle/pluginfile.php/7929315/mod_folder/content/0/goodreads_books.csv?forcedownload=1
#
# ---

# %% [markdown]
# ## Learning Objectives
# - Define and call **functions** with parameters and return values to modularize code
# - Use the **`csv` module** to load structured data from files
# - Use **lists** to store collections of data (rows, columns, or computed values)
# - Use **dictionaries** to organize structured data with meaningful keys
# - Use **sets** to track unique values and eliminate duplicates
# - Use **tuples** for immutable, ordered data where appropriate
# - Combine data structures and functions to build a small data-processing pipeline
#
# ### What's Allowed / Not Allowed
# - **Allowed:** All basic Python (functions, lists, dictionaries, sets, tuples), the `csv` module, file I/O, string methods, built-in functions
# - **Not allowed:** Pandas, NumPy, Matplotlib, or other external libraries
# - **Tip:** Think about **reusability**. Write functions you could use again with different datasets!

# %% [markdown]
# ## How to Work on this Notebook
#
# - Read the instructions in each Part.
# - Check the cells right below the instructions - you'll see either `# YOUR CODE HERE` or `#TODO` comments. That's where you'll have to put your code or modify the existing code!

# %% [markdown]
# ## Part 1: Data Structure Plan (10 points)
#
# Before writing any code, briefly describe your plan for this assignment. Double-click the cell below and write 2-3 sentences covering:
#
# - What is your dataset?
# - Which columns from your dataset will you focus on, and what types will you convert them to (e.g., `int`, `float`, `str`)?
# - Which column will you use for finding unique values (set) and counting occurrences (dictionary)?

# %% [markdown]
# **My data structure plan (TODO: Answer the questions above; double-click this cell to edit the text):**
#
# My dataset is goodreads_books.csv which contains the title of books, author name, average user ratings, publication dates etc.
#
# I will focus on columns such as title which will be of type str, average_rating which will be of type float, and ratings_count which will be of type int.
#
# I will use the average_rating column for finding unique values using the set data structure and counting occurrences using the dictionary.

# %% [markdown]
# ## Part 2: Load Data (15 points)
#
# Write a function `load_data(filepath)` that:
# 1. Opens the file safely using `with open(...)`.
# 2. Uses `csv.reader(...)` to read the file.
# 3. Reads the first row and stores it as a **list of column names** (the header).
# 4. Reads the remaining rows and stores each one as a **list** (or **tuple** if you prefer immutability).
# 5. Returns two things:
#    - The header (as a list)
#    - A **list of rows**, where each row is a list (or tuple) of field values.
#
# **Function signature:**
# ```python
# def load_data(filepath):
#     # Your code here
#     return header, rows
# ```
#
# > **Note:** If your file uses a delimiter other than a comma (e.g., `\t` for tabs or `;`),
# > you can pass it to `csv.reader` like this: `csv.reader(f, delimiter=";")`.
# > Feel free to add a `delimiter` parameter to your function if you need one.
#
# **After defining the function:**
# - Call it with the path to your dataset (e.g., `"my_data.csv"`).
# - Print the header.
# - Print the first 5 rows to verify it works.
# - Print the total number of rows loaded.

# %%
import csv

# Part 2: YOUR CODE HERE
def load_data(filepath:str) -> list:
    with open(filepath, "r") as file:
        contents = csv.reader(file, delimiter=",")
        contents = list(contents)
        header = contents[0]
        rows = contents[1:]
        return header, rows   


header, rows = load_data("./data/goodreads_books.csv")
#print header
print(f"header: {header}")
#print first 5 rows
for i in range(len(rows)):
    if i == 5:
        break
    else:
        print(rows[i])

#print total number of rows loaded
print(f"Total number of rows loaded: {len(rows)}")
# Out:
# header: ['bookID', 'title', 'authors', 'average_rating', 'isbn', 'isbn13', 'language_code', '  num_pages', 'ratings_count', 'text_reviews_count', 'publication_date', 'publisher']
# ['1', 'Harry Potter and the Half-Blood Prince (Harry Potter  #6)', 'J.K. Rowling/Mary GrandPré', '4.57', '0439785960', '9780439785969', 'eng', '652', '2095690', '27591', '9/16/2006', 'Scholastic Inc.']
# ['2', 'Harry Potter and the Order of the Phoenix (Harry Potter  #5)', 'J.K. Rowling/Mary GrandPré', '4.49', '0439358078', '9780439358071', 'eng', '870', '2153167', '29221', '9/1/2004', 'Scholastic Inc.']
# ['4', 'Harry Potter and the Chamber of Secrets (Harry Potter  #2)', 'J.K. Rowling', '4.42', '0439554896', '9780439554893', 'eng', '352', '6333', '244', '11/1/2003', 'Scholastic']
# ['5', 'Harry Potter and the Prisoner of Azkaban (Harry Potter  #3)', 'J.K. Rowling/Mary GrandPré', '4.56', '043965548X', '9780439655484', 'eng', '435', '2339585', '36325', '5/1/2004', 'Scholastic Inc.']
# ...

# %% [markdown]
# ## Part 3: Extract and Clean a Column (20 points)
#
# Write a function `extract_and_clean(rows, col_index, target_type)` that:
# 1. Takes a list of rows, a column index (integer), and a target type (`'int'`, `'float'`, or `'str'`).
# 2. For each row:
#    - Extracts the value at `col_index` (if the row has enough columns; otherwise skip it).
#    - Strips whitespace from the value.
#    - Attempts to convert to the target type.
#    - If conversion fails or the value is empty, appends `None` instead.
# 3. Returns a **list** of cleaned/converted values and a **count of how many values were invalid**.
#
# **Hint:** Use `try` / `except` to catch conversion errors. For example:
# ```python
# try:
#     result = int(value)
# except ValueError:
#     result = None
# ```
#
# **Function signature:**
# ```python
# def extract_and_clean(rows, col_index, target_type):
#     # Your code here
#     return cleaned_data, invalid_count
# ```
#
# **After defining the function:**
# - Use the function to extract and clean 2-3 columns from your data. Look at your header to decide which column index to use for each field.
#   For example, if your header is `['id', 'year', 'category', 'value']`, then `year` is at index `1`, `category` at index `2`, etc.
# - Print the number of invalid values for each column.
# - Print the first 10 cleaned values from each column.

# %%
# Part 3: YOUR CODE HERE

def extract_and_clean(rows: list, col_index: int, target_type):
    cleaned_data = []
    invalid_count = 0
   
    for row in rows:
        #if index out of bound continue to next row:
        if len(row) - 1 < col_index:
            continue
        #fix white spaces
        stripped_value = row[col_index].strip()
        #if the col is empty, append None and continue to next row: 
        if stripped_value == "":
            cleaned_data.append(None)
            invalid_count +=1
            continue
        #type conversion:
        if target_type == "int":
            try:
                cleaned_data.append(int(stripped_value))
            except ValueError:
                cleaned_data.append(None)
                invalid_count += 1
        elif target_type == "float":
            try:
                cleaned_data.append(float(stripped_value))
            except ValueError:
                cleaned_data.append(None)
                invalid_count += 1
        elif target_type == "str":
            cleaned_data.append(str(stripped_value))
    return cleaned_data, invalid_count

#print out num of invalid values for col such as title(str), average rating (float), ratings_count(int)
title_cleaned_data, title_invalid_count = extract_and_clean(rows,header.index("title"),"str")
avg_rating_cleaned_data, avg_rating_invalid_count = extract_and_clean(rows, header.index("average_rating"), "float")
ratings_count_cleaned_data, ratings_count_invalid_count = extract_and_clean(rows, header.index("ratings_count"), "int")
print(f'Invalid counts in the title column: {ratings_count_invalid_count}')
print(f'Invalid counts in the average rating column: {avg_rating_invalid_count}')
print(f'Invalid counts in the ratings count column: {ratings_count_invalid_count}')
#print first 10 clean values from each col
print(f"First 10 cleaned values from title column: {title_cleaned_data[:10]}")
print(f"First 10 cleaned values from average ratings column: {avg_rating_cleaned_data[:10]}")
print(f"First 10 cleaned values from ratings count column: {ratings_count_cleaned_data[:10]}")
# Out:
# Invalid counts in the title column: 0
# Invalid counts in the average rating column: 4
# Invalid counts in the ratings count column: 0
# First 10 cleaned values from title column: ['Harry Potter and the Half-Blood Prince (Harry Potter  #6)', 'Harry Potter and the Order of the Phoenix (Harry Potter  #5)', 'Harry Potter and the Chamber of Secrets (Harry Potter  #2)', 'Harry Potter and the Prisoner of Azkaban (Harry Potter  #3)', 'Harry Potter Boxed Set  Books 1-5 (Harry Potter  #1-5)', 'Unauthorized Harry Potter Book Seven News: "Half-Blood Prince" Analysis and Speculation', 'Harry Potter Collection (Harry Potter  #1-6)', "The Ultimate Hitchhiker's Guide: Five Complete Novels and One Story (Hitchhiker's Guide to the Galaxy  #1-5)", "The Ultimate Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy  #1-5)", "The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy  #1)"]
# ...

# %% [markdown]
# ## Part 4: Unique Values and Occurrence Counts (20 points)
#
# ### Task 4.1: Unique Values with a Set (10 points)
# Using one of your cleaned columns (e.g., categories or years):
# 1. Create a **set** of unique values (excluding `None`).
# 2. Convert the set to a **sorted list** to display the unique values in order.
# 3. Print the number of unique values and the values themselves (or the first 20 if there are many).

# %%
# Task 4.1: YOUR CODE HERE

#Unique values for average_rating column. "None" is excluded
unique_average_rating = set(x for x in avg_rating_cleaned_data if x is not None)
#sort average_rating column
sorted_unique_avg_rating = sorted(unique_average_rating)
#length of unique values
print(f"Length of unique average ratings: {len(sorted_unique_avg_rating)}")
#First 20 values of unique avg ratings
print(f"First 20 values of unique average ratings: {sorted_unique_avg_rating[:20]}")
# Out:
# Length of unique average ratings: 209
# First 20 values of unique average ratings: [0.0, 1.0, 1.67, 2.0, 2.33, 2.4, 2.5, 2.55, 2.61, 2.62, 2.63, 2.67, 2.72, 2.75, 2.77, 2.79, 2.8, 2.81, 2.82, 2.83]

# %% [markdown]
# ### Task 4.2: Count Occurrences with a Dictionary (10 points)
# Write a function `count_occurrences(column_data)` that:
# 1. Takes a list of values (e.g., your cleaned categories).
# 2. Returns a **dictionary** where keys are unique values and values are counts.
# 3. Skips `None` values.
#
# **Function signature:**
# ```python
# def count_occurrences(column_data):
#     # Your code here
#     return counts
# ```
#
# **After defining the function:**
# - Count occurrences for one of your categorical columns.
# - Print the dictionary (or a readable version of it).
# - **Optional:** Print the top 5 most common values (you can use `sorted()` with a key function or just manually inspect).

# %%
# Task 4.2: YOUR CODE HERE

def count_occurrences(column_data: list) -> dict:
    count_dict = {}
    for data in column_data:
        if data not in count_dict:
            count_dict[data] = 1
        else:
            count_dict[data] += 1
    return count_dict

#print average rating cleaned data occurrances
avg_rating_cleaned_data_occurrance = count_occurrences(avg_rating_cleaned_data)
print(avg_rating_cleaned_data_occurrance)

#print top 5 most common values
top_five_by_value = sorted(avg_rating_cleaned_data_occurrance.items(),
           key=lambda item: item[1], reverse=True)[:5]

print(f"Top 5 most occurrances: {top_five_by_value}")
# Out:
# {4.57: 13, 4.49: 13, 4.42: 41, 4.56: 16, 4.78: 2, 3.74: 90, 4.73: 2, 4.38: 46, 4.22: 112, 4.21: 114, 3.44: 30, 3.87: 142, 4.07: 172, 3.9: 156, 3.83: 166, 3.86: 154, 3.91: 152, 3.93: 168, 4.59: 11, 4.5: 41, 4.36: 60, 4.53: 15, 3.84: 138, 3.72: 109, 4.0: 219, 3.88: 155, 4.33: 58, 3.45: 30, 3.76: 122, 3.6: 70, 4.06: 155, 4.17: 155, 3.55: 62, 3.98: 164, 4.13: 143, 3.95: 146, 4.24: 101, 4.34: 46, 3.92: 168, 4.23: 82, 3.75: 96, 3.94: 176, 3.77: 142, 4.46: 15, 3.68: 108, 3.99: 162, 3.25: 16, 3.89: 166, 3.82: 163, 3.78: 115, 4.01: 137, 4.35: 60, 4.28: 76, 3.34: 13, 3.67: 96, 3.48: 26, 3.5: 58, 3.62: 68, 4.27: 90, 3.39: 18, 4.12: 124, 4.08: 146, 4.05: 168, 3.85: 136, 2.99: 1, 4.19: 111, 3.71: 100, 4.2: 92, 3.65: 58, 3.4: 36, 4.11: 151, 3.42: 25, 4.02: 178, 3.69: 83, 4.1: 129, 3.66: 52, 4.61: 8, 4.04: 158, 3.97: 163, 4.14: 140, 3.57: 62, 3.43: 32, 3.22: 8, 3.64: 73, 3.96: 195, 3.8: 145, 3.81: 109, 3.79: 133, 3.23: 8, 4.15: 113, 4.39: 39, 4.03: 134, 3.73: 94, 3.51: 37, 3.63: 73, 3.09: 4, 3.59: 
# ...

# %% [markdown]
# ## Part 5: Numeric Summary (15 points)
#
# Write a function `numeric_summary(values_list)` that:
# 1. Takes a list of numeric values (which may contain `None`).
# 2. Filters out `None` values.
# 3. Returns a **dictionary** with the following keys:
#    - `'count'` - number of valid (non-`None`) values
#    - `'total'` - sum of all valid values
#    - `'min'` - smallest value
#    - `'max'` - largest value
# 4. If there are no valid values, returns a dictionary with all values set to `0` or `None`.
#
# **Hint:** You can use the built-in `sum()`, `min()`, and `max()` functions, or compute them with a loop.
#
# **Function signature:**
# ```python
# def numeric_summary(values_list):
#     # Your code here
#     return summary
# ```
#
# **After defining the function:**
# - Call it on your cleaned numeric column.
# - Print the summary dictionary.
# - Store the result - you'll use it in the report (Part 6).

# %%
# Part 5: YOUR CODE HERE

def numeric_summary(values_list:list) -> dict:
     #filter out none values
     filtered_list = [x for x in values_list if x is not None]
     summary = {"count":len(filtered_list),
               "total":sum(filtered_list),
               "min": min(filtered_list),
               "max": max(filtered_list)}
     return summary
summary = numeric_summary(avg_rating_cleaned_data)  
print(summary)
# Out:
# {'count': 11123, 'total': 43758.72, 'min': 0.0, 'max': 5.0}

# %% [markdown]
# ## Part 6: Summary Report (20 points)
#
# ### Task 6.1: Write a Summary Report (20 points)
# Write a plain-text report `a2_report.txt` that includes:
#
# 1. **Data Loading:**
#    - File path, total rows loaded, sample of header.
#
# 2. **Data Cleaning:**
#    - Number of invalid values per column you cleaned.
#    - Brief note on what types you converted to.
#
# 3. **Unique Values (Sets) and Occurrence Counts (Dictionary):**
#    - Which column you analyzed for unique values.
#    - Count of unique values found.
#    - Examples of unique values (first 20 or so).
#    - Which column you counted; total unique items.
#    - (Optional) Top 3–5 most common values and their counts.
#
# 4. **Numeric Summary:**
#    - Which column you summarized.
#    - Count, total, min, and max.
#
# 5. **Reflection (2-3 sentences):**
#    - How did using **functions** make your code more organized?
#    - What advantages or disadvantages did you find from the data structures you used?
#    - Any challenges you faced or insights you gained?
#
# **Write the report using the `write_report` function provided below.** This function is already provided; for this task you only have to fill in the `report_info` dictionary.

# %%
# Task 6.1: Write summary report


# THE write_report FUNCTION IS PROVIDED; DO NOT CHANGE IT!
def write_report(filepath, data_info):
    """
    Write a summary report to a text file.

    IMPORTANT: This function is provided to you. You shouldn't change it!
    Instead, change the report_info dictionary below.

    Parameters:
        filepath (str): Path to the output report file
        data_info (dict): Dictionary containing summary information
    """
    with open(filepath, 'w', encoding='utf-8') as f:
        f.write("Assignment 2 - Summary Report\n")
        f.write("==============================\n\n")

        # Section 1: Data Loading
        f.write("=== Data Loading ===\n")
        f.write(f"File path: {data_info['filepath']}\n")
        f.write(f"Total rows loaded: {data_info['total_rows']}\n")
        if data_info['header']:
            f.write(f"Header: {data_info['header']}\n")
        f.write("\n")

        # Section 2: Data Cleaning
        f.write("=== Data Cleaning ===\n")
        for col_name, invalid_count in data_info['cleaning_results']:
            f.write(f"  Invalid values in '{col_name}': {invalid_count}\n")
        f.write("\n")

        # Section 3: Unique Values + Counts
        f.write("=== Unique Values (Set Analysis) ===\n")
        f.write(f"Column analyzed: {data_info['unique_col_name']}\n")
        f.write(f"Number of unique values: {data_info['unique_count']}\n")
        f.write(f"Examples: {data_info['unique_examples']}\n")
        f.write("\n")

        f.write("=== Occurrence Counts (Dictionary Analysis) ===\n")
        f.write(f"Column analyzed: {data_info['count_col_name']}\n")
        f.write(f"Total unique items: {data_info['count_unique']}\n")
        if data_info['top_counts']:
            f.write("Top values:\n")
            for item, count in data_info['top_counts']:
                f.write(f"  {item}: {count}\n")
        f.write("\n")

        # Section 4: Numeric Summary
        f.write("=== Numeric Summary ===\n")
        f.write(f"Column analyzed: {data_info['summary_col_name']}\n")
        for key, val in data_info['numeric_summary'].items():
            f.write(f"  {key}: {val}\n")
        f.write("\n")

        # Section 5: Reflection
        f.write("=== Reflection ===\n")
        f.write(data_info['reflection'])
        f.write("\n")


# --- Collect your summary data ---
# TODO: Fill in with your actual variable names and results.
#       The keys below must match what write_report() expects.

report_info = {
    # Data loading (Task 2.1)
    'filepath': '/data/goodreads_books.csv',  # TODO: Replace with your filename
    'header': header,             # TODO: Replace with your header variable
    'total_rows': len(rows),            # TODO: Replace with len(rows)
    
    # Cleaning info (Task 3.1) - a list of (column_name, invalid_count) tuples
    'cleaning_results': [
        ('title', 0),       # TODO: Replace with your column name and invalid count
        ('average_rating', 4),   # TODO: Replace with your column name and invalid count
        ('ratings_count', 0),      # TODO: Replace with your column name and invalid count
    ],

    # Unique values info (Task 4.1)
    'unique_col_name': 'sorted_unique_avg_rating',  # TODO: Change to the column you analyzed
    'unique_count': len(sorted_unique_avg_rating),              # TODO: len() of your unique set
    'unique_examples': sorted_unique_avg_rating[:20],          # TODO: your sorted unique list, first 20

    # Count info (Task 4.2)
    'count_col_name': 'average_rating',  # TODO: Change to the column you analyzed
    'count_unique': len(avg_rating_cleaned_data_occurrance),             # TODO: len() of your counts dict
    'top_counts': top_five_by_value,              # TODO: sorted_counts[:5] or []; leave empty if you skipped the optional part

    # Numeric summary (Task 5.1)
    'summary_col_name': 'average_rating',  # TODO: Change to the column you summarized
    'numeric_summary': summary,        # TODO: Replace with your summary dictionary

    # Reflection
    'reflection': 'In this assignment, I used functions to make my code more organized, reusable, and easier to maintain. '
    '\nI used data structures such as lists, sets, dictionaries, and tuples to clean, store, and process data from goodreads_book.csv, with each structure providing different advantages depending on the task. '
    '\nA challenge I faced was handling missing values during data cleaning, which helped me understand the importance of validating data before analysis.'  # TODO: Write 2-3 sentences reflecting on:
                                             # - How functions improved your code organization
                                             # - Advantages/disadvantages of the data structures
                                             # - Any challenges or insights
}

# Write the report
write_report('a2_report.txt', report_info)
print("Wrote report to a2_report.txt")
# Out:
# Wrote report to a2_report.txt

# %% [markdown]
# ---
#
# ## Submission Checklist
# **Note:** If you double-click this cell and replace the space between the stright brackets below with an X, it'll render as a checkmark!
# - [ ] **Part 1:** Data structure plan completed
# - [ ] **Part 2:** `load_data()` function defined and tested; header and rows printed
# - [ ] **Part 3:** `extract_and_clean()` function defined; columns extracted, cleaned, and previewed
# - [ ] **Part 4:** Set of unique values created; `count_occurrences()` function defined; dictionary of counts displayed
# - [ ] **Part 5:** `numeric_summary()` function defined; summary dictionary printed
# - [ ] **Part 6:** `a2_report.txt` written using the `write_report()` function; reflection completed
# - [ ] All code cells run without errors
# - [ ] Student name and dataset information filled in at the top
# - [ ] Notebook (.ipynb file) and dataset uploaded to Moodle
#
# ### Tips for Success
# - Test each code cell as you go
# - Use descriptive variable names
# - Add comments (using `#`) to explain what your code does
#
# ### Academic Integrity
# Work individually. You may discuss general approaches with classmates, but all code must be your own.
